# %%
import numpy as np
import pandas as pd

# %%
series=pd.Series([49,43,65,40,160])
series
# Out:
# 0     49
# 1     43
# 2     65
# 3     40
# 4    160
# dtype: int64

# %%
series.dtype
# Out:
# dtype('int64')

# %%
series.name="Pokemon Savunma Güçleri"
series
# Out:
# 0     49
# 1     43
# 2     65
# 3     40
# 4    160
# Name: Pokemon Savunma Güçleri, dtype: int64

# %%
series.index=["Bulbasaur","Charmander", "Squirtle" ,"Pikachu","Onix"]
series
# Out:
# Bulbasaur      49
# Charmander     43
# Squirtle       65
# Pikachu        40
# Onix          160
# Name: Pokemon Savunma Güçleri, dtype: int64

# %%
pd.Series({"Balbasaur" :49 , "Charmander":43, "Squirtle":65 ,"Pikachu" : 40,"Onix":160})
series
# Out:
# Bulbasaur      49
# Charmander     43
# Squirtle       65
# Pikachu        40
# Onix          160
# Name: Pokemon Savunma Güçleri, dtype: int64

# %%
series["Pikachu"]
series.iloc[3]
# Out:
# np.int64(40)

# %%
series[["Bulbasaur" , "Pikachu"]]
series.iloc[[0,3]]
series["Bulbasaur":"Pikachu"]
# Out:
# Bulbasaur     49
# Charmander    43
# Squirtle      65
# Pikachu       40
# Name: Pokemon Savunma Güçleri, dtype: int64

# %%
series>40
# Out:
# Bulbasaur      True
# Charmander     True
# Squirtle       True
# Pikachu       False
# Onix           True
# Name: Pokemon Savunma Güçleri, dtype: bool

# %%
series[series>40]
# Out:
# Bulbasaur      49
# Charmander     43
# Squirtle       65
# Onix          160
# Name: Pokemon Savunma Güçleri, dtype: int64

# %%
series[series>series.mean()]
# Out:
# Onix    160
# Name: Pokemon Savunma Güçleri, dtype: int64

# %%
series["Pikachu"]=70
series
# Out:
# Bulbasaur      49
# Charmander     43
# Squirtle       65
# Pikachu        70
# Onix          160
# Name: Pokemon Savunma Güçleri, dtype: int64

# %%
series[series>series.mean()]=50
series
# Out:
# Bulbasaur     49
# Charmander    43
# Squirtle      65
# Pikachu       70
# Onix          50
# Name: Pokemon Savunma Güçleri, dtype: int64

# %%
series = pd.Series({ 'Bulbasaur': 49, 'Charmander': 43, 'Squirtle': 65, 'Pikachu': 40, 'Onix': 160 },
name="Pokemon Savunma Güçleri")
series
# Out:
# Bulbasaur      49
# Charmander     43
# Squirtle       65
# Pikachu        40
# Onix          160
# Name: Pokemon Savunma Güçleri, dtype: int64

# %%
pokemon = pd.DataFrame({
'atak': [49, 52, 48, 55, 45], 'savunma': [49, 43, 65, 40, 160], 'hız': [45, 65, 43, 90, 70],
'tür': ['ot', 'ateş', 'su', 'elektrik', 'kaya'] },
index=["Bulbasaur", "Charmander", "Squirtle", "Pikachu", "Onix"])
pokemon
# Out:
#             atak  savunma  hız       tür
# Bulbasaur     49       49   45        ot
# Charmander    52       43   65      ateş
# Squirtle      48       65   43        su
# Pikachu       55       40   90  elektrik
# Onix          45      160   70      kaya

# %%
pokemon.columns
#pokemon.index
# Out:
# Index(['atak', 'savunma', 'hız', 'tür'], dtype='object')

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Bulbasaur to Onix
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   atak     5 non-null      int64
#  1   savunma  5 non-null      int64
#  2   hız      5 non-null      int64
#  3   tür      5 non-null      object
# dtypes: int64(3), object(1)
# memory usage: 372.0+ bytes

# %%
pokemon.size
# Out:
# 20

# %%
pokemon.shape
# Out:
# (5, 4)

# %%
pokemon.describe()
# Out:
#             atak     savunma        hız
# count   5.000000    5.000000   5.000000
# mean   49.800000   71.400000  62.600000
# std     3.834058   50.460876  19.398454
# min    45.000000   40.000000  43.000000
# 25%    48.000000   43.000000  45.000000
# 50%    49.000000   49.000000  65.000000
# 75%    52.000000   65.000000  70.000000
# max    55.000000  160.000000  90.000000

# %%
pokemon["atak"]
# Out:
# Bulbasaur     49
# Charmander    52
# Squirtle      48
# Pikachu       55
# Onix          45
# Name: atak, dtype: int64

# %%
pokemon.iloc[2] #indexi getirir
# Out:
# atak       48
# savunma    65
# hız        43
# tür        su
# Name: Squirtle, dtype: object

# %%
pokemon.loc["Pikachu"]
# Out:
# atak             55
# savunma          40
# hız              90
# tür        elektrik
# Name: Pikachu, dtype: object

# %%
pokemon["hız"]>60
# Out:
# Bulbasaur     False
# Charmander     True
# Squirtle      False
# Pikachu        True
# Onix           True
# Name: hız, dtype: bool

# %%
pokemon[pokemon["hız"]>60]
# Out:
#             atak  savunma  hız       tür
# Charmander    52       43   65      ateş
# Pikachu       55       40   90  elektrik
# Onix          45      160   70      kaya

# %%
pokemon.loc[pokemon["hız"]>60 , "hız"]
# Out:
# Charmander    65
# Pikachu       90
# Onix          70
# Name: hız, dtype: int64

# %%
pokemon.drop("Onix" , inplace=True)
pokemon
# Out:
#             atak  savunma  hız       tür
# Bulbasaur     49       49   45        ot
# Charmander    52       43   65      ateş
# Squirtle      48       65   43        su
# Pikachu       55       40   90  elektrik

# %%
pokemon.drop("tür" , axis=1)
# Out:
#             atak  savunma  hız
# Bulbasaur     49       49   45
# Charmander    52       43   65
# Squirtle      48       65   43
# Pikachu       55       40   90
# Onix          45      160   70

# %%
pokemon[["atak" , "savunma"]]/10
# Out:
#             atak  savunma
# Bulbasaur    4.9      4.9
# Charmander   5.2      4.3
# Squirtle     4.8      6.5
# Pikachu      5.5      4.0

# %%
pokemon[["atak" , "savunma"]] + [10 , 5]
# Out:
#             atak  savunma
# Bulbasaur     59       54
# Charmander    62       48
# Squirtle      58       70
# Pikachu       65       45

# %%
boy=pd.Series([0.7 , 0.6 , 0.5 ,0.4] , index=pokemon.index)
boy
# Out:
# Bulbasaur     0.7
# Charmander    0.6
# Squirtle      0.5
# Pikachu       0.4
# dtype: float64

# %%
pokemon["boy"]=boy
pokemon
# Out:
#             atak  savunma  hız       tür  boy
# Bulbasaur     49       49   45        ot  0.7
# Charmander    52       43   65      ateş  0.6
# Squirtle      48       65   43        su  0.5
# Pikachu       55       40   90  elektrik  0.4

# %%
pokemon["boy"]=1
pokemon
# Out:
#             atak  savunma  hız       tür  boy
# Bulbasaur     49       49   45        ot    1
# Charmander    52       43   65      ateş    1
# Squirtle      48       65   43        su    1
# Pikachu       55       40   90  elektrik    1

# %%
pokemon.rename(columns={"atak":"attack"})
# Out:
#             attack  savunma  hız       tür  boy
# Bulbasaur       49       49   45        ot    1
# Charmander      52       43   65      ateş    1
# Squirtle        48       65   43        su    1
# Pikachu         55       40   90  elektrik    1

# %%
pokemon["toplam güç"]=pokemon["atak"]+pokemon["savunma"]+pokemon["hız"]
pokemon
# Out:
#             atak  savunma  hız       tür  boy  toplam güç
# Bulbasaur     49       49   45        ot    1         143
# Charmander    52       43   65      ateş    1         160
# Squirtle      48       65   43        su    1         156
# Pikachu       55       40   90  elektrik    1         185

# %%
pokemon2 = pd.DataFrame({
'atak': [49, np.nan, 48, np.nan, 45], 'savunma': [np.nan, 43, 65, 40, np.nan], 'hız': [45, 65, 43, 90, 70],
 },
index=["Bulbasaur", "Charmander", "Squirtle", "Pikachu", "Onix"])
pokemon2
# Out:
#             atak  savunma  hız
# Bulbasaur   49.0      NaN   45
# Charmander   NaN     43.0   65
# Squirtle    48.0     65.0   43
# Pikachu      NaN     40.0   90
# Onix        45.0      NaN   70

# %%
pokemon2.dropna()
# Out:
#           atak  savunma  hız tür
# Squirtle  48.0     65.0   43  su

# %%
pokemon2.isnull()
# Out:
#              atak  savunma    hız    tür
# Bulbasaur   False     True  False  False
# Charmander   True    False  False  False
# Squirtle    False    False  False  False
# Pikachu      True    False  False  False
# Onix        False     True  False  False

# %%
pokemon2.fillna(0)
# Out:
#             atak  savunma  hız       tür
# Bulbasaur   49.0      0.0   45        ot
# Charmander   0.0     43.0   65      ateş
# Squirtle    48.0     65.0   43        su
# Pikachu      0.0     40.0   90  elektrik
# Onix        45.0      0.0   70      kaya

# %%
pokemon2.fillna(pokemon2.mean())
# Out:
#                  atak    savunma  hız
# Bulbasaur   49.000000  49.333333   45
# Charmander  47.333333  43.000000   65
# Squirtle    48.000000  65.000000   43
# Pikachu     47.333333  40.000000   90
# Onix        45.000000  49.333333   70

# %%
pokemon2
# Out:
#             atak  savunma  hız
# Bulbasaur   49.0      NaN   45
# Charmander   NaN     43.0   65
# Squirtle    48.0     65.0   43
# Pikachu      NaN     40.0   90
# Onix        45.0      NaN   70

# %%
pokemon2.fillna(method="ffill")
# Out:
# /tmp/ipython-input-1073295630.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pokemon2.fillna(method="ffill")
#             atak  savunma  hız
# Bulbasaur   49.0      NaN   45
# Charmander  49.0     43.0   65
# Squirtle    48.0     65.0   43
# Pikachu     48.0     40.0   90
# Onix        45.0     40.0   70

# %%
pokemon2.fillna(method="bfill")
# Out:
# /tmp/ipython-input-3665316483.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pokemon2.fillna(method="bfill")
#             atak  savunma  hız
# Bulbasaur   49.0     43.0   45
# Charmander  48.0     43.0   65
# Squirtle    48.0     65.0   43
# Pikachu     45.0     40.0   90
# Onix        45.0      NaN   70

# %%
elciler = pd.Series([ 'France', 'United Kingdom', 'United Kingdom', 'Italy', 'Germany', 'Germany', 'Germany', ], index=[
'Gérard Araud', 'Kim Darroch', 'Peter Westmacott', 'Armando Varricchio', 'Peter Wittig', 'Peter Ammon', 'Klaus Scharioth ' ])
elciler
# Out:
# Gérard Araud                  France
# Kim Darroch           United Kingdom
# Peter Westmacott      United Kingdom
# Armando Varricchio             Italy
# Peter Wittig                 Germany
# Peter Ammon                  Germany
# Klaus Scharioth              Germany
# dtype: object

# %%
elciler.duplicated()
# Out:
# Gérard Araud          False
# Kim Darroch           False
# Peter Westmacott       True
# Armando Varricchio    False
# Peter Wittig          False
# Peter Ammon            True
# Klaus Scharioth        True
# dtype: bool

# %%
elciler.drop_duplicates(keep=False)
# Out:
# Gérard Araud          France
# Armando Varricchio     Italy
# dtype: object

# %%
df = pd.DataFrame({ 'Veri': [ '1987_E_ABD _1', '1990?_E_ING_1', '1992_K_ABD_2', '1970?_E_ IT_1', '1985_K_I T_2' ]})
df
# Out:
#             Veri
# 0  1987_E_ABD _1
# 1  1990?_E_ING_1
# 2   1992_K_ABD_2
# 3  1970?_E_ IT_1
# 4   1985_K_I T_2

# %%
df["Veri"].str.split("_")
# Out:
# 0    [1987, E, ABD , 1]
# 1    [1990?, E, ING, 1]
# 2     [1992, K, ABD, 2]
# 3    [1970?, E,  IT, 1]
# 4     [1985, K, I T, 2]
# Name: Veri, dtype: object

# %%
df["Veri"].str.split("_" , expand=True)
# Out:
#        0  1     2  3
# 0   1987  E  ABD   1
# 1  1990?  E   ING  1
# 2   1992  K   ABD  2
# 3  1970?  E    IT  1
# 4   1985  K   I T  2

# %%
df2=df["Veri"].str.split("_" , expand=True)
df2.columns=["Yıl", "Cinsiyet", "Ülke", "Çocuk Sayısı"]
df2
# Out:
#      Yıl Cinsiyet  Ülke Çocuk Sayısı
# 0   1987        E  ABD             1
# 1  1990?        E   ING            1
# 2   1992        K   ABD            2
# 3  1970?        E    IT            1
# 4   1985        K   I T            2

# %%
df2["Yıl"].str.contains("\?")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\?'
# <>:1: SyntaxWarning: invalid escape sequence '\?'
# /tmp/ipython-input-3924919776.py:1: SyntaxWarning: invalid escape sequence '\?'
#   df2["Yıl"].str.contains("\?")
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: Yıl, dtype: bool
